# %% [markdown]
# <a href="https://colab.research.google.com/github/LivaIg/Diabetes-classification/blob/main/diabetes_classification_neural__networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Diabetes Prediction Challange with neural networks**
# Task is to build a machine learning classifier that predicts whether a patient is diagnosed with diabetes or not, based on a set of health indicators.
#
# The dataset includes 21 features describing lifestyle, demographic, and health-related factors (e.g., BMI, smoking status, physical activity, age, blood pressure, cholesterol levels, etc.).

# %%
#loading packages
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, BatchNormalization, Dropout, Activation
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras import regularizers
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Loding data sets

# %%
X_test = pd.read_csv('X_test.csv')
y_train_df = pd.read_csv('y_train.csv')
X_train_df = pd.read_csv('X_train.csv')

# %% [markdown]
# Droping ID column

# %%
if 'ID' in X_train_df.columns:
    X_train_df = X_train_df.drop('ID', axis=1)
if 'ID' in X_test.columns:
    X_test = X_test.drop('ID', axis=1)

print(X_train_df.head())
print(X_train_df.info())

# %% [markdown]
# # Prepare data and split into train-test data

# %%
y_train_mapped = y_train_df['Diabetes'].map({'Yes': 1, 'No': 0}).values

# Split training data into training and validation sets
X_train, x_val, y_train, y_val = train_test_split(
    X_train_df,
    y_train_mapped,
    test_size=0.1,
    random_state=42,
    stratify=y_train_mapped
)

# %% [markdown]
# # One hot encoder for gender column

# %%
enc = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

# 1. Encode Gender for TRAINING set (X_train)
gender_encoded_train = enc.fit_transform(X_train[["Gender"]])
gender_encoded_train_df = pd.DataFrame(
    gender_encoded_train,
    columns=enc.get_feature_names_out(["Gender"]),
    index=X_train.index
)

# 2. Encode Gender for VALIDATION set (x_val)
gender_encoded_val = enc.transform(x_val[["Gender"]])
gender_encoded_val_df = pd.DataFrame(
    gender_encoded_val,
    columns=enc.get_feature_names_out(["Gender"]),
    index=x_val.index
)

# 3. Drop original Gender column and concatenate encoded columns
X_train = pd.concat([X_train.drop("Gender", axis=1), gender_encoded_train_df], axis=1)
x_val = pd.concat([x_val.drop("Gender", axis=1), gender_encoded_val_df], axis=1)

# %% [markdown]
# # Performing Scaling

# %%
# Identify all numerical columns (all columns remaining should be numerical/scaled features)
numerical_cols = X_train.columns

# Initialize and fit the scaler on the TRAINING data ONLY
scaler = StandardScaler()
X_train[numerical_cols] = scaler.fit_transform(X_train[numerical_cols])

# Apply the same scaler (using .transform) to the validation data
x_val[numerical_cols] = scaler.transform(x_val[numerical_cols])

# Adjusting to the right format for TensorFlow
X_train = X_train.astype('float32')
x_val = x_val.astype('float32')
y_train = np.array(y_train).reshape(-1).astype('float32')
y_val = np.array(y_val).reshape(-1).astype('float32')

# %% [markdown]
# # Model testing with diverging parameters(layers, batch size, epochs, dropaout, normalization etc.)

# %%
early_stopping = EarlyStopping(
    min_delta=0.001, # minimium amount of change
    monitor='val_loss',
    patience=15, # how many epochs to wait before stopping
    restore_best_weights=True,
)


_epochs = 100
_batch_size = 16
_lr = 0.0001


# Build medium model
model_small = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(64, kernel_regularizer=regularizers.l2(0.001)),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
])


model_small.compile(optimizer=Adam(learning_rate=_lr),
              loss='binary_crossentropy',
              metrics=['accuracy'])


history_small = model_small.fit(X_train, y_train,
                                  validation_data=(x_val, y_val),
                                  callbacks=[early_stopping],
                                  epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.6071 - loss: 0.7142 - val_accuracy: 0.7346 - val_loss: 0.5538
# Epoch 2/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7276 - loss: 0.5718 - val_accuracy: 0.7452 - val_loss: 0.5394
# Epoch 3/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7342 - loss: 0.5601 - val_accuracy: 0.7471 - val_loss: 0.5329
# Epoch 4/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7423 - loss: 0.5480 - val_accuracy: 0.7522 - val_loss: 0.5285
# Epoch 5/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7416 - loss: 0.5438 - val_accuracy: 0.7516 - val_loss: 0.5254
# Epoch 6/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7427 - loss: 0.5420 - val_accuracy: 0.7524 - val_loss: 0.5226
# Epoch 7/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7469 - loss: 0.5367 - val_accuracy: 0.7522 - val_loss: 0.5201
# Epoch 8/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7456 - loss: 0.5348 - val_accuracy: 0.7514 - val_loss: 0.5181
# Epoch 9/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7505 - loss: 0.5281 - val_accuracy: 0.7527 - val_loss: 0.5165
# Epoch 10/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7459 - loss: 0.5329 - val_accuracy: 0.7518 - val_loss: 0.5153
# Epoch 11/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7468 - loss: 0.5292 - val_accuracy: 0.7535 - val_loss: 0.5137
# Epoch 12/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7517 - loss: 0.5202 - val_accuracy: 0.7571 - val_loss: 0.5125
# Epoch 13/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7489 - loss: 0.5265 - val_accuracy: 0.7533 - val_loss: 0.5113
# Epoch 14/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7514 - loss: 0.5256 - val_accuracy: 0.7563 - val_loss: 0.5104
# Epoch 15/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7479 - loss: 0.5271 - val_accuracy: 0.7559 - val_loss: 0.5097
# Epoch 16/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7486 - loss: 0.5245 - val_accuracy: 0.7563 - val_loss: 0.5087
# Epoch 17/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7485 - loss: 0.5245 - val_accuracy: 0.7561 - val_loss: 0.5077
# Epoch 18/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7482 - loss: 0.5216 - val_accuracy: 0.7542 - val_loss: 0.5073
# Epoch 19/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7529 - loss: 0.5202 - val_accuracy: 0.7554 - val_loss: 0.5065
# Epoch 20/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7500 - loss: 0.5183 - val_accuracy: 0.7569 - val_loss: 0.5061
# Epoch 21/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7481 - loss: 0.5204 - val_accuracy: 0.7552 - val_loss: 0.5061
# Epoch 22/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7461 - loss: 0.5232 - val_accuracy: 0.7573 - val_loss: 0.5049
# Epoch 23/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7517 - loss: 0.5140 - val_accuracy: 0.7563 - val_loss: 0.5044
# Epoch 24/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7508 - loss: 0.5135 - val_accuracy: 0.7571 - val_loss: 0.5041
# Epoch 25/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7513 - loss: 0.5135 - val_accuracy: 0.7573 - val_loss: 0.5035
# Epoch 26/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7514 - loss: 0.5171 - val_accuracy: 0.7584 - val_loss: 0.5029
# Epoch 27/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7528 - loss: 0.5101 - val_accuracy: 0.7563 - val_loss: 0.5026
# Epoch 28/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7530 - loss: 0.5113 - val_accuracy: 0.7576 - val_loss: 0.5023
# Epoch 29/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7522 - loss: 0.5101 - val_accuracy: 0.7576 - val_loss: 0.5019
# Epoch 30/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7562 - loss: 0.5088 - val_accuracy: 0.7584 - val_loss: 0.5015
# Epoch 31/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7544 - loss: 0.5100 - val_accuracy: 0.7567 - val_loss: 0.5008
# Epoch 32/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7523 - loss: 0.5129 - val_accuracy: 0.7586 - val_loss: 0.5008
# Epoch 33/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7514 - loss: 0.5131 - val_accuracy: 0.7582 - val_loss: 0.5006
# Epoch 34/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7536 - loss: 0.5089 - val_accuracy: 0.7586 - val_loss: 0.5006
# Epoch 35/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7517 - loss: 0.5148 - val_accuracy: 0.7590 - val_loss: 0.4994
# Epoch 36/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7536 - loss: 0.5090 - val_accuracy: 0.7593 - val_loss: 0.4995
# Epoch 37/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7519 - loss: 0.5112 - val_accuracy: 0.7584 - val_loss: 0.4994
# Epoch 38/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7535 - loss: 0.5118 - val_accuracy: 0.7590 - val_loss: 0.4992
# Epoch 39/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7516 - loss: 0.5108 - val_accuracy: 0.7595 - val_loss: 0.4993
# Epoch 40/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7513 - loss: 0.5116 - val_accuracy: 0.7590 - val_loss: 0.4988
# Epoch 41/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7514 - loss: 0.5096 - val_accuracy: 0.7605 - val_loss: 0.4987
# Epoch 42/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7506 - loss: 0.5129 - val_accuracy: 0.7614 - val_loss: 0.4985
# Epoch 43/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7539 - loss: 0.5092 - val_accuracy: 0.7605 - val_loss: 0.4982
# Epoch 44/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7556 - loss: 0.5081 - val_accuracy: 0.7603 - val_loss: 0.4980
# Epoch 45/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7506 - loss: 0.5103 - val_accuracy: 0.7575 - val_loss: 0.4984
# Epoch 46/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7546 - loss: 0.5073 - val_accuracy: 0.7590 - val_loss: 0.4979
# Epoch 47/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7540 - loss: 0.5112 - val_accuracy: 0.7599 - val_loss: 0.4978
# Epoch 48/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7573 - loss: 0.5074 - val_accuracy: 0.7586 - val_loss: 0.4973
# Epoch 49/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7540 - loss: 0.5082 - val_accuracy: 0.7603 - val_loss: 0.4971
# Epoch 50/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7556 - loss: 0.5078 - val_accuracy: 0.7586 - val_loss: 0.4976
# Epoch 51/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7537 - loss: 0.5055 - val_accuracy: 0.7597 - val_loss: 0.4976
# Epoch 52/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7517 - loss: 0.5117 - val_accuracy: 0.7612 - val_loss: 0.4975
# Epoch 53/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7490 - loss: 0.5101 - val_accuracy: 0.7616 - val_loss: 0.4968
# Epoch 54/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7531 - loss: 0.5074 - val_accuracy: 0.7599 - val_loss: 0.4971
# Epoch 55/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7528 - loss: 0.5080 - val_accuracy: 0.7603 - val_loss: 0.4970
# Epoch 56/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7541 - loss: 0.5048 - val_accuracy: 0.7584 - val_loss: 0.4970
# Epoch 57/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7532 - loss: 0.5067 - val_accuracy: 0.7601 - val_loss: 0.4968
# Epoch 58/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7571 - loss: 0.5074 - val_accuracy: 0.7603 - val_loss: 0.4969
# Epoch 59/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7552 - loss: 0.5042 - val_accuracy: 0.7580 - val_loss: 0.4973
# Epoch 60/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7492 - loss: 0.5114 - val_accuracy: 0.7588 - val_loss: 0.4967
# Epoch 61/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7514 - loss: 0.5090 - val_accuracy: 0.7597 - val_loss: 0.4962
# Epoch 62/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7547 - loss: 0.5023 - val_accuracy: 0.7591 - val_loss: 0.4963
# Epoch 63/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7523 - loss: 0.5077 - val_accuracy: 0.7605 - val_loss: 0.4965
# Epoch 64/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7537 - loss: 0.5072 - val_accuracy: 0.7616 - val_loss: 0.4959
# Epoch 65/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7503 - loss: 0.5088 - val_accuracy: 0.7593 - val_loss: 0.4965
# Epoch 66/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7540 - loss: 0.5062 - val_accuracy: 0.7576 - val_loss: 0.4964
# Epoch 67/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7546 - loss: 0.5062 - val_accuracy: 0.7599 - val_loss: 0.4961
# Epoch 68/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7532 - loss: 0.5078 - val_accuracy: 0.7625 - val_loss: 0.4960
# Epoch 69/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7546 - loss: 0.5069 - val_accuracy: 0.7597 - val_loss: 0.4964
# Epoch 70/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7516 - loss: 0.5073 - val_accuracy: 0.7597 - val_loss: 0.4973
# Epoch 71/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7537 - loss: 0.5057 - val_accuracy: 0.7607 - val_loss: 0.4961
# Epoch 72/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7554 - loss: 0.5040 - val_accuracy: 0.7608 - val_loss: 0.4958
# Epoch 73/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7555 - loss: 0.5055 - val_accuracy: 0.7633 - val_loss: 0.4964
# Epoch 74/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7522 - loss: 0.5074 - val_accuracy: 0.7601 - val_loss: 0.4961
# Epoch 75/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7505 - loss: 0.5086 - val_accuracy: 0.7616 - val_loss: 0.4957
# Epoch 76/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7533 - loss: 0.5075 - val_accuracy: 0.7597 - val_loss: 0.4959
# Epoch 77/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7544 - loss: 0.5063 - val_accuracy: 0.7620 - val_loss: 0.4966
# Epoch 78/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7521 - loss: 0.5064 - val_accuracy: 0.7624 - val_loss: 0.4962
# Epoch 79/100
# 1492/1492 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7519 - loss: 0.5088 - val_accuracy: 0.7631 - val_loss: 0.4957
